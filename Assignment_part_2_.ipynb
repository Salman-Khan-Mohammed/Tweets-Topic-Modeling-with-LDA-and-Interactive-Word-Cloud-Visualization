# %% [markdown]
# ## In this assignment, you will write Python scripts to download Tweets for any Twitter account OR News using any News API. Then, on the downloaded tweets, you need to apply the following:
# 1.	Cleaning of the tweets or News
# 2.	Apply LDA for topic modeling; you can run LDA for 10-15 topics.
# 3.	Based on the Topic\term strength, you need to create a word cloud
# 4.	When a word is clicked, then it should display the related tweets for that word.

# %% [markdown]
# ## Step 1 : - Scrapping the Tweets from twitter using NTScraper

# %%
# installing the required library

# %%
pip install ntscraper
# Out:
# Requirement already satisfied: ntscraper in /opt/homebrew/anaconda3/lib/python3.11/site-packages (0.3.13)
# Requirement already satisfied: requests in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from ntscraper) (2.31.0)
# Requirement already satisfied: beautifulsoup4 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from ntscraper) (4.12.2)
# Requirement already satisfied: lxml in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from ntscraper) (4.9.3)
# Requirement already satisfied: soupsieve>1.2 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from beautifulsoup4->ntscraper) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from requests->ntscraper) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from requests->ntscraper) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from requests->ntscraper) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from requests->ntscraper) (2024.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install wordcloud
# Out:
# Collecting wordcloud
#   Downloading wordcloud-1.9.3-cp311-cp311-macosx_11_0_arm64.whl.metadata (3.4 kB)
# Requirement already satisfied: numpy>=1.6.1 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from wordcloud) (1.26.4)
# Requirement already satisfied: pillow in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from wordcloud) (10.2.0)
# Requirement already satisfied: matplotlib in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from wordcloud) (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from matplotlib->wordcloud) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from matplotlib->wordcloud) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Downloading wordcloud-1.9.3-cp311-cp311-macosx_11_0_arm64.whl (168 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.3/168.3 kB 5.4 MB/s eta 0:00:00
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.9.3
# Note: you may need to restart the kernel to use updated packages.

# %%
# importing required libraries 
from ntscraper import Nitter
import pandas as pd

# %% [markdown]
# ### The message indicates that NumExpr is set to use 8 threads by default for its computations. This number corresponds to the number of threads it will use to execute operations in parallel.

# %%
def create_tweets_dataset(username, no_of_tweets):
    scraper = Nitter()
    tweets = scraper.get_tweets(username, mode="user", number=no_of_tweets)

    # Creating a Dictionary to store the tweets data
    data = {
        'link': [],
        'text': [],
        'username': [],  # Adding 'username' column
        'user': [],
        'likes': [],
        'quotes': [],
        'retweets': [],
        'comments': []
    }

    for tweet in tweets['tweets']:
        data['link'].append(tweet['link'])
        data['text'].append(tweet['text'])
        data['username'].append(username)
        data['user'].append(tweet['user']['name'])
        data['likes'].append(tweet['stats']['likes'])
        data['retweets'].append(tweet['stats']['retweets'])
        data['quotes'].append(tweet['stats']['quotes'])
        data['comments'].append(tweet['stats']['comments'])

    df = pd.DataFrame(data)

    # Writing to CSV file
    csv_filename = username + "_tweets_data.csv"
    df.to_csv(csv_filename, index=False)
    print(f"Completed scraping. '{csv_filename}' is ready!")

# %%
create_tweets_dataset("elonmusk",100)
# Out:
# Testing instances: 100%|████████████████████████| 77/77 [01:20<00:00,  1.04s/it]
# 16-Jun-24 16:01:46 - No instance specified, using random instance https://nitter.qwik.space
# 16-Jun-24 16:01:52 - Current stats for elonmusk: 19 tweets, 0 threads...
# 16-Jun-24 16:01:56 - Current stats for elonmusk: 38 tweets, 0 threads...
# 16-Jun-24 16:02:00 - Current stats for elonmusk: 57 tweets, 0 threads...
# 16-Jun-24 16:02:04 - Current stats for elonmusk: 77 tweets, 0 threads...
# 16-Jun-24 16:02:08 - Current stats for elonmusk: 97 tweets, 0 threads...
# 16-Jun-24 16:02:12 - Current stats for elonmusk: 100 tweets, 0 threads...
# Completed scraping. 'elonmusk_tweets_data.csv' is ready!

# %% [markdown]
# ## Scrapping for different Usernames

# %% [markdown]
# ### Marques Bownlee

# %%
create_tweets_dataset("MKBHD",100)
# Out:
# Testing instances: 100%|████████████████████████| 77/77 [01:08<00:00,  1.13it/s]
# 16-Jun-24 15:59:55 - No instance specified, using random instance https://nitter.soopy.moe
# 16-Jun-24 16:00:02 - Current stats for MKBHD: 18 tweets, 0 threads...
# 16-Jun-24 16:00:07 - Current stats for MKBHD: 38 tweets, 0 threads...
# 16-Jun-24 16:00:12 - Current stats for MKBHD: 58 tweets, 0 threads...
# 16-Jun-24 16:00:17 - Current stats for MKBHD: 76 tweets, 0 threads...
# 16-Jun-24 16:00:21 - Current stats for MKBHD: 95 tweets, 0 threads...
# 16-Jun-24 16:00:26 - Current stats for MKBHD: 100 tweets, 0 threads...
# Completed scraping. 'MKBHD_tweets_data.csv' is ready!

# %% [markdown]
# ### sama : - Sam Altman

# %%
create_tweets_dataset("sama",100)
# Out:
# Testing instances: 100%|████████████████████████| 77/77 [01:11<00:00,  1.08it/s]
# 16-Jun-24 16:03:23 - No instance specified, using random instance https://nitter.soopy.moe
# 16-Jun-24 16:03:31 - Current stats for sama: 20 tweets, 0 threads...
# 16-Jun-24 16:03:35 - Current stats for sama: 40 tweets, 0 threads...
# 16-Jun-24 16:03:40 - Current stats for sama: 57 tweets, 0 threads...
# 16-Jun-24 16:03:45 - Current stats for sama: 77 tweets, 0 threads...
# 16-Jun-24 16:03:50 - Current stats for sama: 97 tweets, 0 threads...
# 16-Jun-24 16:03:55 - Current stats for sama: 100 tweets, 0 threads...
# Completed scraping. 'sama_tweets_data.csv' is ready!

# %% [markdown]
# ### AndrewYNg : - Andrew Coursera founder

# %%
create_tweets_dataset("AndrewYNg",100)
# Out:
# Testing instances: 100%|████████████████████████| 77/77 [01:23<00:00,  1.09s/it]
# 16-Jun-24 16:05:19 - No instance specified, using random instance https://nitter.kavin.rocks
# 16-Jun-24 16:05:25 - Current stats for AndrewYNg: 21 tweets, 0 threads...
# 16-Jun-24 16:05:29 - Current stats for AndrewYNg: 41 tweets, 0 threads...
# 16-Jun-24 16:05:34 - Current stats for AndrewYNg: 61 tweets, 0 threads...
# 16-Jun-24 16:05:38 - Current stats for AndrewYNg: 79 tweets, 0 threads...
# 16-Jun-24 16:05:42 - Current stats for AndrewYNg: 98 tweets, 0 threads...
# 16-Jun-24 16:05:47 - Current stats for AndrewYNg: 100 tweets, 0 threads...
# Completed scraping. 'AndrewYNg_tweets_data.csv' is ready!

# %% [markdown]
# ### geoffreyhinton : - Geoffrey Hinton

# %%
create_tweets_dataset("geoffreyhinton",100)
# Out:
# Testing instances: 100%|████████████████████████| 77/77 [01:14<00:00,  1.04it/s]
# 16-Jun-24 16:25:59 - No instance specified, using random instance https://nitter.lunar.icu
# 16-Jun-24 16:26:04 - Current stats for geoffreyhinton: 20 tweets, 0 threads...
# 16-Jun-24 16:26:09 - Current stats for geoffreyhinton: 40 tweets, 0 threads...
# 16-Jun-24 16:26:13 - Current stats for geoffreyhinton: 60 tweets, 0 threads...
# 16-Jun-24 16:26:16 - Current stats for geoffreyhinton: 73 tweets, 0 threads...
# 16-Jun-24 16:26:18 - Empty page on https://nitter.lunar.icu
# Completed scraping. 'geoffreyhinton_tweets_data.csv' is ready!

# %% [markdown]
# ### Yann LeCun :- Chief AI Scientist at Meta

# %%
create_tweets_dataset("ylecun",100)
# Out:
# Testing instances: 100%|████████████████████████| 77/77 [01:14<00:00,  1.04it/s]
# 16-Jun-24 16:08:34 - No instance specified, using random instance https://nitter.lunar.icu
# 16-Jun-24 16:08:39 - Current stats for ylecun: 20 tweets, 0 threads...
# 16-Jun-24 16:08:44 - Current stats for ylecun: 40 tweets, 0 threads...
# 16-Jun-24 16:08:48 - Current stats for ylecun: 60 tweets, 0 threads...
# 16-Jun-24 16:08:52 - Current stats for ylecun: 80 tweets, 0 threads...
# 16-Jun-24 16:08:57 - Current stats for ylecun: 100 tweets, 0 threads...
# Completed scraping. 'ylecun_tweets_data.csv' is ready!

# %% [markdown]
# ### karpathy : -Andrej Karpathy  Director of AI @ Tesla

# %%
create_tweets_dataset("karpathy",100)
# Out:
# Testing instances: 100%|████████████████████████| 77/77 [01:20<00:00,  1.05s/it]
# 16-Jun-24 16:10:17 - No instance specified, using random instance https://bird.habedieeh.re
# 16-Jun-24 16:10:22 - Current stats for karpathy: 21 tweets, 0 threads...
# 16-Jun-24 16:10:26 - Current stats for karpathy: 41 tweets, 0 threads...
# 16-Jun-24 16:10:30 - Current stats for karpathy: 61 tweets, 0 threads...
# 16-Jun-24 16:10:34 - Current stats for karpathy: 81 tweets, 0 threads...
# 16-Jun-24 16:10:38 - Current stats for karpathy: 100 tweets, 0 threads...
# Completed scraping. 'karpathy_tweets_data.csv' is ready!

# %% [markdown]
# ### tim_cook : - Tim Cook CEO Apple

# %%
create_tweets_dataset("tim_cook",100)
# Out:
# Testing instances: 100%|████████████████████████| 77/77 [01:10<00:00,  1.08it/s]
# 16-Jun-24 16:11:49 - No instance specified, using random instance https://bird.habedieeh.re
# 16-Jun-24 16:11:54 - Current stats for tim_cook: 20 tweets, 0 threads...
# 16-Jun-24 16:11:57 - Current stats for tim_cook: 40 tweets, 0 threads...
# 16-Jun-24 16:12:01 - Current stats for tim_cook: 60 tweets, 0 threads...
# 16-Jun-24 16:12:05 - Current stats for tim_cook: 80 tweets, 0 threads...
# 16-Jun-24 16:12:09 - Current stats for tim_cook: 100 tweets, 0 threads...
# Completed scraping. 'tim_cook_tweets_data.csv' is ready!

# %% [markdown]
# ### mustafasuleyman : - Mustafa Suleyman CEO, Microsoft AI

# %%
create_tweets_dataset("mustafasuleyman",100)
# Out:
# Testing instances: 100%|████████████████████████| 77/77 [01:11<00:00,  1.08it/s]
# 16-Jun-24 16:21:10 - No instance specified, using random instance https://nitter.kavin.rocks
# 16-Jun-24 16:21:16 - Current stats for mustafasuleyman: 20 tweets, 0 threads...
# 16-Jun-24 16:21:20 - Current stats for mustafasuleyman: 37 tweets, 0 threads...
# 16-Jun-24 16:21:25 - Current stats for mustafasuleyman: 53 tweets, 0 threads...
# 16-Jun-24 16:21:29 - Current stats for mustafasuleyman: 70 tweets, 0 threads...
# 16-Jun-24 16:21:33 - Current stats for mustafasuleyman: 89 tweets, 0 threads...
# 16-Jun-24 16:21:37 - Current stats for mustafasuleyman: 100 tweets, 0 threads...
# Completed scraping. 'mustafasuleyman_tweets_data.csv' is ready!

# %% [markdown]
# ### demishassabis : - Demis Hassabis Co-founder & CEO
# @GoogleDeepMind

# %%
create_tweets_dataset("demishassabis",100)
# Out:
# Testing instances: 100%|████████████████████████| 77/77 [01:19<00:00,  1.03s/it]
# 16-Jun-24 16:16:30 - No instance specified, using random instance https://nitter.bird.froth.zone
# 16-Jun-24 16:16:40 - https://nitter.bird.froth.zone unreachable. Trying https://nitter.qwik.space
# 16-Jun-24 16:16:47 - Current stats for demishassabis: 20 tweets, 0 threads...
# 16-Jun-24 16:16:51 - Current stats for demishassabis: 39 tweets, 0 threads...
# 16-Jun-24 16:16:55 - Current stats for demishassabis: 59 tweets, 0 threads...
# 16-Jun-24 16:17:00 - Current stats for demishassabis: 79 tweets, 0 threads...
# 16-Jun-24 16:17:04 - Current stats for demishassabis: 97 tweets, 0 threads...
# 16-Jun-24 16:17:08 - Current stats for demishassabis: 100 tweets, 0 threads...
# Completed scraping. 'demishassabis_tweets_data.csv' is ready!

# %% [markdown]
# ### ClementDelangue : - Co-founder & CEO
# @HuggingFace

# %%
create_tweets_dataset("ClementDelangue",100)
# Out:
# Testing instances: 100%|████████████████████████| 77/77 [01:12<00:00,  1.07it/s]
# 16-Jun-24 16:29:11 - No instance specified, using random instance https://nitter.tiekoetter.com
# 16-Jun-24 16:29:18 - Current stats for ClementDelangue: 21 tweets, 0 threads...
# 16-Jun-24 16:29:22 - Current stats for ClementDelangue: 41 tweets, 0 threads...
# 16-Jun-24 16:29:26 - Current stats for ClementDelangue: 61 tweets, 0 threads...
# 16-Jun-24 16:29:31 - Current stats for ClementDelangue: 80 tweets, 0 threads...
# 16-Jun-24 16:29:35 - Current stats for ClementDelangue: 100 tweets, 0 threads...
# Completed scraping. 'ClementDelangue_tweets_data.csv' is ready!

# %% [markdown]
# ## Merging Multiple CSV Files

# %%
import pandas as pd
import glob

# Path to the directory containing your CSV files
csv_files = glob.glob('/Users/salmanmohamm3d/Desktop/Social M A/assignment part2 /*.csv')

# List to hold the DataFrames for each file
dfs = []

# Iterate over the list of CSV files
for csv_file in csv_files:
    # Read each CSV file into a DataFrame
    df = pd.read_csv(csv_file)
    # Append the DataFrame to the list
    dfs.append(df)

# Concatenate all DataFrames in the list along the rows (axis=0)
merged_df = pd.concat(dfs, ignore_index=True)

# Path and filename to save the merged CSV file
merged_csv_file = '/Users/salmanmohamm3d/Desktop/Social M A/final_dataset.csv'

# Write the merged DataFrame to a CSV file
merged_df.to_csv(merged_csv_file, index=False)

print(f'Merged CSV file and saved in {merged_csv_file}')
# Out:
# Merged CSV file and saved in /Users/salmanmohamm3d/Desktop/Social M A/final_dataset.csv

# %% [markdown]
# ## Step 2 : - Cleaning of the tweets

# %%
# Importing Libraries

# %%
import nltk
import re

# %%
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/salmanmohamm3d/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/salmanmohamm3d/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/salmanmohamm3d/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# %%
df = pd.read_csv('/Users/salmanmohamm3d/Desktop/Social M A/assignment part2 /final_dataset.csv')

# %% [markdown]
# ## Cleaning the Final Dataset

# %%
def clean_tweet(tweet):
    if pd.isna(tweet):
        return ''
    # Removing URLs
    tweet = re.sub(r"http\S+|www\S+|https\S+", '', tweet)
    # Removing special characters and numbers
    tweet = re.sub(r'[^\w\s]', '', tweet)
    # Tokenizing
    tokens = word_tokenize(tweet)
    # Removing stopwords
    stop_words = set(stopwords.words('english'))
    tokens = [word for word in tokens if word.lower() not in stop_words]
    # Lemmatizing
    lemmatizer = WordNetLemmatizer()
    tokens = [lemmatizer.lemmatize(word) for word in tokens]
    # Joining tokens back into a string
    clean_tweet = ' '.join(tokens)

    return clean_tweet


df = df

# Clean and preprocess 'text' column using clean_tweet function
df['cleaned_text'] = df['text'].apply(clean_tweet)

# Drop rows where 'cleaned_text' is empty or NaN
df = df.dropna(subset=['cleaned_text'])
df = df[df['cleaned_text'] != '']

# Tokenize the cleaned text
tokenize_tweets = [text.split() for text in df['cleaned_text']]

# Create a dictionary of terms
dictionary = Dictionary(tokenize_tweets)

# Continue with the rest of your code as needed (e.g., creating bag of words representation, saving to CSV)
df.to_csv('cleaned_tweets.csv', index=False)
print("cleaned_tweets.csv is ready!")
# Out:
# 16-Jun-24 16:53:37 - adding document #0 to Dictionary<0 unique tokens: []>
# 16-Jun-24 16:53:37 - built Dictionary<6513 unique tokens: ['adding', 'board', 'critical', 'excited', 'expertise']...> from 1138 documents (total 19511 corpus positions)
# 16-Jun-24 16:53:37 - Dictionary lifecycle event {'msg': "built Dictionary<6513 unique tokens: ['adding', 'board', 'critical', 'excited', 'expertise']...> from 1138 documents (total 19511 corpus positions)", 'datetime': '2024-06-16T16:53:37.425864', 'gensim': '4.3.0', 'python': '3.11.7 (main, Dec 15 2023, 12:09:56) [Clang 14.0.6 ]', 'platform': 'macOS-15.0-arm64-arm-64bit', 'event': 'created'}
# cleaned_tweets.csv is ready!

# %% [markdown]
# ## Step 4 & Step 5: - Appling LDA for topic modeling & Creating a word Cloud based on the Topic Strength

# %%
df = pd.read_csv('/Users/salmanmohamm3d/Desktop/Social M A/assignment part2 /cleaned_tweets.csv')

# %%
# Importing libraries÷
import pandas as pd
from gensim.models import LdaModel
from gensim.corpora import Dictionary
from wordcloud import WordCloud
import plotly.express as px
from nltk.corpus import stopwords as nltk_stopwords

# Tokenization
tokenize_tweets = [tweet.split() for tweet in df['cleaned_text']]
dictionary = Dictionary(tokenize_tweets)

# Creating a bag of words representation of corpus
corpus = [dictionary.doc2bow(tokens) for tokens in tokenize_tweets]

# Applying LDA with number of topics = 10
num_topics = 10
lda_model = LdaModel(corpus=corpus, id2word=dictionary, num_topics=num_topics)

# Stopwords for English
stopwords = set(nltk_stopwords.words('english'))

# Creating word clouds and bar plots for each topic
for topic_id in range(lda_model.num_topics):
    # Generate a word cloud image
    wordcloud_dict = dict(lda_model.show_topic(topic_id, 10))
    wordcloud = WordCloud(background_color="white", stopwords=stopwords).generate_from_frequencies(wordcloud_dict)
    
    # Most frequent word in the topic
    most_frequent_word = max(wordcloud.words_.items(), key=lambda x: x[1])[0]
    
    # Convert word cloud to Plotly Express format
    word_freq_tuples = [(word, freq) for word, freq in wordcloud.words_.items()]
    wordcloud_df = pd.DataFrame(word_freq_tuples, columns=['word', 'frequency'])
    
    # Plotting word cloud
    fig_wordcloud = px.imshow(wordcloud)
    fig_wordcloud.update_layout(title=f"Word Cloud for the Topic :- {most_frequent_word}")
    fig_wordcloud.show()
    
    # Bar plot for each topic
    fig_bar = px.bar(wordcloud_df, x='word', y='frequency', title=f"Bar Plot for the Topic :- {most_frequent_word}",
                     labels={'word': 'Word', 'frequency': 'Frequency'})
    fig_bar.show()
# Out:
# 18-Jun-24 18:08:07 - adding document #0 to Dictionary<0 unique tokens: []>
# 18-Jun-24 18:08:07 - built Dictionary<6513 unique tokens: ['adding', 'board', 'critical', 'excited', 'expertise']...> from 1138 documents (total 19511 corpus positions)
# 18-Jun-24 18:08:07 - Dictionary lifecycle event {'msg': "built Dictionary<6513 unique tokens: ['adding', 'board', 'critical', 'excited', 'expertise']...> from 1138 documents (total 19511 corpus positions)", 'datetime': '2024-06-18T18:08:07.197063', 'gensim': '4.3.0', 'python': '3.11.7 (main, Dec 15 2023, 12:09:56) [Clang 14.0.6 ]', 'platform': 'macOS-15.0-arm64-arm-64bit', 'event': 'created'}
# 18-Jun-24 18:08:07 - using symmetric alpha at 0.1
# 18-Jun-24 18:08:07 - using symmetric eta at 0.1
# 18-Jun-24 18:08:07 - using serial LDA version on this node
# 18-Jun-24 18:08:07 - running online (single-pass) LDA training, 10 topics, 1 passes over the supplied corpus of 1138 documents, updating model once every 1138 documents, evaluating perplexity every 1138 documents, iterating 50x with a convergence threshold of 0.001000
# 18-Jun-24 18:08:07 - too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy
# 18-Jun-24 18:08:07 - -13.294 per-word bound, 10040.8 perplexity estimate based on a held-out corpus of 1138 documents with 19511 words
# 18-Jun-24 18:08:07 - PROGRESS: pass 0, at document #1138/1138
# 18-Jun-24 18:08:07 - topic #0 (0.100): 0.006*"new" + 0.006*"Apple" + 0.004*"Pro" + 0.004*"everyone" + 0.004*"Gemini" + 0.003*"AI" + 0.003*"iPad" + 0.003*"team" + 0.003*"LLMs" + 0.003*"ever"
# 18-Jun-24 18:08:07 - topic #5 (0.100): 0.005*"technology" + 0.005*"team" + 0.005*"AI" + 0.005*"time" + 0.004*"love" + 0.004*"Gemma" + 0.003*"Im" + 0.003*"first" + 0.003*"world" + 0.003*"today"
# 18-Jun-24 18:08:07 - topic #2 (0.100): 0.020*"AI" + 0.006*"year" + 0.005*"new" + 0.005*"work" + 0.003*"open" + 0.003*"model" + 0.003*"world" + 0.003*"US" + 0.003*"going" + 0.003*"would"
# 18-Jun-24 18:08:07 - topic #7 (0.100): 0.004*"AI" + 0.004*"dog" + 0.004*"human" + 0.004*"model" + 0.003*"future" + 0.003*"year" + 0.003*"u" + 0.003*"Apple" + 0.003*"making" + 0.003*"great"
# 18-Jun-24 18:08:07 - topic #3 (0.100): 0.015*"AI" + 0.005*"new" + 0.005*"Apple" + 0.004*"world" + 0.004*"course" + 0.004*"people" + 0.003*"application" + 0.003*"New" + 0.003*"one" + 0.003*"model"
# 18-Jun-24 18:08:07 - topic diff=6.820796, rho=1.000000
# 18-Jun-24 18:08:07 - LdaModel lifecycle event {'msg': 'trained LdaModel<num_terms=6513, num_topics=10, decay=0.5, chunksize=2000> in 0.31s', 'datetime': '2024-06-18T18:08:07.518865', 'gensim': '4.3.0', 'python': '3.11.7 (main, Dec 15 2023, 12:09:56) [Clang 14.0.6 ]', 'platform': 'macOS-15.0-arm64-arm-64bit', 'event': 'created'}

# %% [markdown]
# ## Step 6 : - Displaying all related tweets when a selected word is given as input from the Word Cloud.

# %% [markdown]
# ## Printing related tweets & number of tweets for the given word from the word cloud

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Aggregate words from all topics to create a single word cloud
all_words = {}
tweet_count = 0  # Initialize tweet count
for topic_id in range(lda_model.num_topics):
    wordcloud_dict = dict(lda_model.show_topic(topic_id, 10))
    for word, freq in wordcloud_dict.items():
        all_words[word] = all_words.get(word, 0) + freq

# Generate word cloud image from aggregated words
wordcloud = WordCloud(background_color="white", stopwords=stopwords).generate_from_frequencies(all_words)

# Plot word cloud
plt.figure(figsize=(10, 7))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Combined Word Cloud')
plt.show()

# Define function to display related tweets for a given word
def display_related_tweets(word):
    related_tweets = df[df['cleaned_text'].str.contains(word)]
    tweet_count = related_tweets.shape[0]  # Get the number of related tweets
    print(f"Number of tweets containing '{word}': {tweet_count}")
    for tweet in related_tweets['text']:
        print(tweet)

# Get input word from user
word_clicked = input("Enter a word from the word cloud: ")

# Display related tweets for the input word
display_related_tweets(word_clicked)
# Out:
# Enter a word from the word cloud:  AI
# Number of tweets containing 'AI': 273
# We’re really grateful to Jan for everything he's done for OpenAI, and we know he'll continue to contribute to the mission from outside. In light of the questions his departure has raised, we wanted to explain a bit about how we think about our overall strategy.  First, we have…
# Ilya and OpenAI are going to part ways. This is very sad to me; Ilya is easily one of the greatest minds of our generation, a guiding light of our field, and a dear friend. His brilliance and vision are well known; his warmth and compassion are less well known but no less…
# it is available to all ChatGPT users, including on the free plan! so far, GPT-4 class models have only been available to people who pay a monthly subscription. this is important to our mission; we want to put great AI tools in the hands of everyone.
# we want to give users lots of control of AI within some hard boundaries that society eventually agrees on; this is another step.  i'm really happy with how it came out.  a lot of people worked hard on this, but i want to especially thank @joannejang and @johnschulman2
# happy to see this—excited for intel, the US, and more AI capacity!
# wow. The new model from @LumaLabsAI extending images into videos is really something else. I understood intuitively that this would become possible very soon, but it's still something else to see it and think through future iterations of.  A few more examples around, e.g. the…
# Actually, really liked the Apple Intelligence announcement. It must be a very exciting time at Apple as they layer AI on top of the entire OS. A few of the major themes.  Step 1 Multimodal I/O. Enable text/audio/image/video capability, both read and write. These are the native…
# If you tuned in to WWDC to see what Apple is doing with AI, we're all probably thinking the same thing around now 50 minutes into it... 🫠
# # Reproduce GPT-2 (124M) in llm.c in 90 minutes for $20 ✨  The GPT-2 (124M) is the smallest model in the GPT-2 series released by OpenAI in 2019, and is actually quite accessible today, even for the GPU poor. For example, with llm.c you can now reproduce this model on one 8X…
# Congrats to @AIatMeta on Llama 3 release!! 🎉 https://ai.meta.com/blog/meta-llama-3/ Notes:  Releasing 8B and 70B (both base and finetuned) models, strong-performing in their model class (but we'll see when the rankings come in @ @lmsysorg  :)) 400B is still training, but already encroaching…
# +1 to the best AI newsletter atm that I enjoy skimming, great/ambitious work by @swyx & friends:  https://buttondown.email/ainews/archive/  "Skimming" because they are very long. Not sure how it is built, sounds like there is a lot of LLM aid going on indexing ~356 Twitters, ~21 Discords, etc.
# Hi everyone yes, I left OpenAI yesterday. First of all nothing "happened" and it’s not a result of any particular event, issue or drama (but please keep the conspiracy theories coming as they are highly entertaining :)). Actually, being at OpenAI over the last ~year has been…
# Applications are open for batch 3 of aigrant.com for pre-seed and seed-stage companies building AI products! Deadline is Feb 16.  As an experiment, this batch we are offering the option of either receiving $250k on an uncapped note, or $2.5M at a $25M cap.
# The open-source AI revolution hasn’t happened yet!  Yes we have impressive open-weights models, and thank you to those publishing weights, but if you can’t reproduce the model then it’s not truly open-source.  Imagine if Linux published only a binary without the codebase. Or…
# # Portrayals of AI People sometimes read a bit too specifically into my bio "Building a kind of JARVIS".   I name JARVIS in general terms only, as one of my favorite popular portrayals of an AI - a helpful, conversational, empowering e/ia automation. An aid against evil and…
# I’m playing around with calling our tech, as it is today, IA (intelligence amplification) instead of AI. IA have the vibe of tools for thought, needing human interaction, and resemble a lot more what we actually have today. AI feels more like independent long-running agents.
# What would be the "benefit of hindsight" truths to tell Licklider at this time, with our knowledge today?  1. You're on the right track w.r.t. Intelligence Augmentation lasting a long time. And "thinking centers". 2. All of "AI" for *thinking* that you know and is currently…
# Andrew Ng says California's proposed bill SB-1047 would stifle innovation in open source, and poses a specter of liability on builders of AI for anything nefarious their models are adapted to do
# New Retrieval Augmented Generation Benchmark from @AIatMeta! 🚀 Comprehensive RAG Benchmark (CRAG) is the RAG benchmark for factual question-answering consisting of 4,409 question-answer pairs with mock APIs to simulate retrieval for evaluating LLMs.  CRAG Tasks: 1️⃣ Retrieval…
# 🎉🎉🎉 Celebrating 3 million downloads of @AIatMeta's llama 3 model from Ollama!   Thank you @Meta for supporting and embracing open-source!   ollama run llama3
# Professor Anthony Fauci ForMemRS becomes a Foreign Member of the Royal Society. He was a key advisor to seven Presidents on global HIV/AIDS issues and on preparedness against emerging infectious disease threats, and served as the Chief Medical Advisor to President Joe Biden.…
# So while Silicon Valley tries to block open source AI  China moved ahead with   - qwen2 72B, sliding pass Facebook llama3 70B with clean Apache2 license - kling, launches a sora like model, before sora  Like they really dun care about your fears or world view, and accelerate
# Hilarious that U.S. politicians & investors in proprietary LLMs think they are going to slow down Chinese AI efforts by passing legislation in the U.S.   U.S. legislation will slow-down U.S. innovation, & result in Chinese lead.   See below:
# Stop AI ppl causally alluding to doing terr*r*sm against AI labs?  Extremists gonna extreme I guess... Not good.
# The US is going to lose its leadership in AI if it doesn't support more open research and open-source AI!
# 🚨job alert:  a research engineer position just opened in our Brain & AI team, in FAIR Paris @AIatMeta : https://www.metacareers.com/jobs/1428273181902592/
# The reality is that the critics of this bill are wildly bipartisan, ranging from socialists to Randians. Substantively, Senator Wiener’s amendments do not alleviate that group’s concerns. SB 1047 is still incompatible with open source, and still harms California’s AI industry.
# If this CA AI bill passes, it will be a huge boon for VC investors in WA, TX, MA, NY, and FL. Easier for entrepreneurs to relocate than to be exposed to such a large unknown new risk.
# The valley is starting to wake up and push back against UC Berkeley CAIS and Scott Weiner's anti-innovation efforts.   https://www.bloomberg.com/news/newsletters/2024-06-06/silicon-valley-is-on-alert-over-an-ai-bill-in-california?accessToken=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzb3VyY2UiOiJTdWJzY3JpYmVyR2lmdGVkQXJ0aWNsZSIsImlhdCI6MTcxNzcwNjM3NywiZXhwIjoxNzE4MzExMTc3LCJhcnRpY2xlSWQiOiJTRU9EQkREV0xVNjgwMCIsImJjb25uZWN0SWQiOiJFODA3NUYyRkZGMjA0NUI2QTlEQzA5M0EyQTdEQTE4NiJ9.inmKq7Cjba9mv9X5ZL4ZnyNqfuMa2xKvU0lIiVlbr1w
# Nice analysis of how California's AI safety regulation misses the distinction between technology and applications. It's a bit like trying to ensure that computers can only be sold if they can't be used for bad things. Here's our essay that Andrew mentions https://www.aisnakeoil.com/p/ai-safety-is-not-a-model-property
# “Imagine if we passed a law that says if anyone uses a motor in a harmful way, the *motor manufacturer* is liable.”  This would be ridiculous. Well that is what California’s SB-1047 is proposing for AI models.  Regulate the application. Not the math.
# I share @AndrewYNg's serious concerns with much of the open-source and broader AI community about California’s SB-1047 proposal.   Among many issues, the covered models definitions, shutdown capability, and enormous cost for compliance would be a huge blow to both CA and US…
# "California’s latest AI safety bill is driven by fears that another Donald Trump presidency would overturn federal efforts to rein in the technology"  ... CAIS/Weiner are cramming a terrible bill down our throats in fear of Trump?   What. The. Fuck.  https://semafor.com/article/06/05/2024/ai-safety-bill-driven-by-fears-of-another-donald-trump-presidency
# What role does open source play in the innovation ecosystem? Venture capitalist @pmarca says, “Every new software project starts with open source. Without open source, startups would die and academic computer science would not exist.” @drfeifei #HAIatFive Watch the fireside chat:…
# AI Safety, having failed to convince government of x-risk, is pivoting to NatSec. When all else fails just yell “CHINA” in DC.
# This entire AI safety thing is such a long con.   It was put in motion years ago, and now it's going to directly hurt all of tech, open source, startups and academia.   We need to wake the fuck up and start pushing back.
# The Big AI Debate explained by Forbes. What is more beneficial or more dangerous: open source AI or proprietary controlled by 3 or 4 big players? The people who worry most about AI safety also tend to be he ones who overestimate the power of AI.
# Excellent report on the proper way to use AI in Science.  As usual in machine learning: don't be fooled by good results obtained by testing on the training set.
# It’s personal, powerful, and private—and it’s integrated into the apps you rely on every day.  Introducing Apple Intelligence—our next chapter in AI. https://www.apple.com/newsroom/2024/06/introducing-apple-intelligence-for-iphone-ipad-and-mac/
# We are proud to support @RED and the @GlobalFund in their work to end HIV/AIDS. With the help of our customers around the world, millions in sub-Saharan Africa have received access to lifesaving care. Together, we are making a difference. #WorldAidsDay https://www.apple.com/newsroom/2023/12/apple-marks-world-aids-day-with-red/
# From @saveyrwardrobe’s AI wardrobe maximization tools to @GymStreak’s mobile personal trainer and @nightsky’s magical stargazing app, they’re helping people live better, fuller lives.
# New AI safety paper in Science with a lot of authors: https://www.science.org/doi/10.1126/science.adn0117
# 📰 🎉 #VayuRobotics has been named to the 2024 @CBinsights #AI 100 list in recognition of our novel tech developing AI foundation models for mobility & #robotics. We are honored to be on this list of esteemed companies. Congratulations, Team Vayu! https://www.vayurobotics.com/press-releases/vayu-robotics-named-to-the-2024-cb-insights-ai-100-list
# Yann LeCun thinks the risk of AI taking over is miniscule. This means he puts a big weight on his own opinion and a miniscule weight on the opinions of many other equally qualified experts.
# Fei-Fei Li has written a book. She was the first computer vision researcher to truly understand the power of big data and her work opened the floodgates for deep learning. She delivers a clear-eyed account of the awesome potential and danger of AI. https://www.momentoflift.com/the-worlds-i-see
# Andrew Ng is claiming that the idea that AI could make us extinct is a big-tech conspiracy. A datapoint that does not fit this conspiracy theory is that I left Google so that I could speak freely about the existential threat.
# As underwriters of tomorrow’s innovations, venture capital needs a framework for responsible AI investing. Today Radical Ventures is pleased to share its Responsible AI for Startups (RAIS) framework - an open source resource for investors evaluating investments in AI technologies…
# It seems to me that @VayuRobotics is addressing a great market niche and their approach has fewer ethical problems than many other AI applications. I look forward to working with @nitishsr and his team. (3/3)
# Oct 4th, 4pm ET: Join AI luminaries @geoffreyhinton  and @drfeifei in conversation with Radical's @JordanJacobs10 on building responsible AI systems and how their careers intersected at one of modern AI’s key inflection points. Sign-up here: https://lnkd.in/gqY3yjjU
# Dishonest CBC headline: "Canada's AI pioneer Geoffrey Hinton says AI could wipe out humans. In the meantime, there's money to be made".  The second sentence was said by a journalist, not me, but you wouldn't know that.
# In the NYT today, Cade Metz implies that I left Google so that I could criticize Google. Actually, I left so that I could talk about the dangers of AI without considering how this impacts Google. Google has acted very responsibly.
# AI is eating software. I’ve said this for a while. Why? Traditional software never improves. AI enables ‘smart’ software to learn & improve constantly. The world runs on software and AI is changing everything. Yet few people see or understand the massive AI wave on the horizon.
# I am excited to support @raquelutrasun as she begins her next chapter with @waabi_ai. She has been an AI pioneer for the last 20 years and will bring new thinking to an incredibly important space.
# My friend @Jordanjacobs10 of @RadicalVCFund asked what I thought of the @covariantAI team and technology. I told him I had made a rather small investment (I don't want to reinforce reinforcement learning) but now wished I had invested 100X more. So Radical did (and then some).
# Organizers of data science and machine learning conferences (NeurIPS, ICML, AISTATS, ICLR, UAI, ...): Allow remote paper & poster presentations at conferences - Sign the Petition! chng.it/p8QMVkp7 via @Change
# Suppose you have cancer and you have to choose between a black box AI surgeon that cannot explain how it works but has a 90% cure rate and a human surgeon with an 80% cure rate. Do you want the AI surgeon to be illegal?
# Vector Institute is offering scholarships to top candidates applying to AI Master’s Programs.  Learn more vectorinstitute.ai/aimasters…
# I’m excited to announce that today I’m joining @Microsoft as CEO of Microsoft AI. I’ll be leading all consumer AI products and research, including Copilot, Bing and Edge. My friend and longtime collaborator Karén Simonyan will be Chief Scientist, and several of our amazing…
# AI should be a catalyst for real progress, but too often we haven't seen that. One of the good things about being at @Microsoft is seeing the sheer breadth of effort behind the scenes, particularly with our AI for Good initiatives.   This is AI making a difference to the…
# ‘Browsing’ is about to be completely transformed. Finally, our AIs have learnt to speak our languages, and actually see what we see.  This demo is particularly close to my heart. It completes work that I started at DeepMind back in 2011.
# Just think, 15 years ago, AI could hardly recognize a single object in a 256x256 image.
# We’re reimagining what @MSFTCopilot, your everyday AI companion, can do in @Windows. It will be an app like experience that is simpler and more personal, showing up when and where you need it.
# Standby for more details on the full spectrum of capabilities we are demoing today; they’re coming to every Copilot very soon.  This is an incredibly exciting time. I want to pay tribute to the teams at @Microsoft and @OpenAI who are making this possible.  And especially to…
# Microsoft changed computing history by inventing a new category: the Personal Computer or PC.  Now we’re re-inventing PCs for the AI era, taking us from personal computing to truly personal intelligence.  Today we’re launching a new product category: Copilot+ PCs, the biggest…
# Real personality. Effortless interactions. The ability to see what we see.  ✨  I’ve long argued that AIs with EQ, IQ and AQ are coming. Here’s the first real glimpse of what’s its gonna feel like.  It’s a magical experience: smart, intuitive, natural, and useful.
# We are taking Copilot to the next level. 🚀  Copilot will see, hear, speak and help in real time.  Watch this demo to see what I mean. Soon your AI companion will start to live life alongside you, whether playing Minecraft or helping you navigate life’s most difficult challenges.…
# Responsible AI: "The benefits are incredible. The challenge is how to mitigate the downsides" https://edition.cnn.com/videos/tech/2024/01/07/gps-0107-mustafa-suleyman-on-regulating-ai.cnn
# We’re committed to building and deploying AI responsibly and helping others do the same, which is why we’re sharing details about our approach in this inaugural report.
# Biomimicry can never be underrated as an inspiration for technology (including AI). Almost always nature has found an answer first e.g. a snail robot to scoop up microplastics. https://news.cornell.edu/stories/2023/12/snail-inspired-robot-could-scoop-ocean-microplastics
# Well worth a listen, super interesting as you would expect. Some of the best minds (and all round people) in AI and tech.
# 5/5 At Microsoft AI we are up for this. We are building products and shaping a future of massive positive impact. It's still only the beginning of a long journey ahead, but we have a vision for Copilot that is ambitious and, we believe, truly transformational. I couldn't be more…
# 4/5 Responsible AI is a cornerstone. Everyone is working hard to define new norms and everyone I've met feels a deep responsibility to do so with an open heart and a humble mind... Massive kudos to all the teams working on this!
# 3/5 AI is everything here. @satyanadella and @kevin_scott been so clear about this. Microsoft is a truly AI-first business driving the biggest technological transformation of our time. I knew this already of course... But seeing this in practice, at this scale, is impressive.
# What is an AI anyway? Microsoft AI CEO @mustafasuleyman offers a compelling new vision for the future.  Learn more about where AI is heading by watching his full #TED2024 Talk here: t.ted.com/8S2AAYE
# “What actually is an AI anyway?” Had fun thinking about this question for my @TEDTalks talk which is out now… New technologies need new metaphors. https://www.ted.com/talks/mustafa_suleyman_ai_is_turning_into_something_totally_new
# The new CEO of Microsoft AI, @MustafaSuleyman, with a $100B budget at TED:  "AI is a new digital species."  "To avoid existential risk, we should avoid: 1) Autonomy 2) Recursive self-improvement 3) Self-replication We have a good 5 to 10 years before we'll have to confront this."
# How has #AI become the 21st century's greatest dilemma? Microsoft AI CEO and "The Coming Wave" author @mustafasuleyman weighs in!  Notes https://buff.ly/3VJQPYe  Apple https://buff.ly/3VJQNzA  Spotify https://buff.ly/4a9RE0F  Overcast https://buff.ly/3VJQNQ6
# .@Microsoft making London home to its new AI hub is another huge vote of confidence in the UK’s status as a global leader in AI and our mission to develop it safely – driving innovation and growth across the country 🇬🇧  https://blogs.microsoft.com/blog/2024/04/07/announcing-new-microsoft-ai-hub-in-london/
# Microsoft announces new AI office in UK https://bbc.in/4cOEyYn
# The UK has phenomenal AI talent and a long established culture of responsible AI development.   Today I’m proud to be opening a new office: Microsoft AI London. If you’d like to join us, get in touch. We’re hiring!  https://blogs.microsoft.com/blog/2024/04/07/announcing-new-microsoft-ai-hub-in-london/
# It’s a good day for everyone involved in @inflectionAI. I am excited to work with incoming CEO @seanwhite, who’s been a friend and colleague for more than 20 years. Under Sean’s leadership, Inflection will continue on its mission and will reach more people than ever by making its…
# Welcome to Microsoft, @mustafasuleyman. Thrilled to have you lead Microsoft AI as we build consumer AI, like Copilot, that is loved by and benefits people around the world.
# I'll never not be surprised by some of the uncanny echoes of personhood exhibited by AI. For example, scientists feed random data to AI during "sleep" periods, sparking new connections and boosting creative problem-solving. Research shows new training method inspired by human…
# Anyone arguing that AI isn't tackling major challenges isn't paying attention. Everyone knows batteries are integral to the clean energy transition but aren't where we need them to be. Now we're seeing serious strides in new battery materials thanks to AI, which narrowed 32…
# Everyone is going to be represented by AI. You are going to have AI representing your interests on your behalf, presenting your brand value, your ideas…it will be your interlocutor the-coming-wave.com
# Language, agriculture, writing—each was a general-purpose technology at the center of an early wave. These three waves formed the foundation of civilization as we know it. Now we take them for granted. It will be the same for AI. the-coming-wave.com
# It's the best time to be an inventor and a creator!    @mustafasuleyman, AI thought-leader reflects on AI's vast potential - from mundane gadgets to varied industries.   "We were fundamentally long term thinkers from the beginning and we resisted the temptation to optimize for…
# Therapeutic breakthroughs & new insights are rising because the costs of sequencing are plummeting. The trajectories of technologies like AI and bio are stark and powerful. Read them and we read the future. https://www.globalxetfs.com/charting-disruption-medical-breakthroughs/
# Costs in areas like healthcare and education have, for basic economic reasons, outstripped inflation for years. At some stage they will become unaffordable, to societies and many households. It would be crazy to say AI has all the answers. It's equally crazy to believe that we…
# Find the "AI partner that completes you". Welcome to the @pi fan club!https://www.forbes.com/sites/forbesbooksauthors/2024/02/05/piai-vs-chatgpt-why-i-am-cheating-on-my-first-ai/?sh=74e566572c27
# "If you really focus on creating an AI that's smooth, conversational, fluent, very even-handed and balanced, it turns out it's possible to do it. Pi very kind, balanced and friendly and that demonstrates that we can actually control these AI systems." https://edition.cnn.com/videos/tv/2024/02/01/amanpour-mustafa-suleyman-artificial-intelligence.cnn
# We welcome the Tech Accord to Combat Deceptive Use of AI in 2024 Elections.   In a year of unprecedented elections around the world, trust and transparency are more important than ever to democracy.
# Ready for a future where I can ask my friends and colleagues less stupid questions. 😁🙏  Are you excited about the future of AI? Join us on Feb 29 for the first-ever Masters of AI Day!  Learn more & register: hubs.la/Q02jqctf0  🎥 @inflectionAI co-founder @mustafasuleyman
# We welcome NIST’s AI Safety Institute. Safety sits at the heart of our mission and culture at Inflection.   We’re excited to share our expertise as part of the AI Safety Institute Consortium to help ensure that AI benefits everyone. #AISIC
# AIs will have infinitely more capable sensors than humans... check out this paper showing super-resolution cancer cell detection in pathology slides. https://www.pennmedicine.org/news/news-releases/2024/january/ai-tool-brings-precision-pathology-for-cancer-into-focus
# Would you let @elonmusk chip your brain? @inflectionAI’s @mustafasuleyman, who co-founded @GoogleDeepMind, isn’t ruling it out.  Hear our fascinating conversation on everything from deepfake porn to Putin’s digital doppelganger. #TheAmanpourHour airs 11aET Saturdays on @CNN
# It’s actually quite incredible to be alive at this moment. It’s hard to fully absorb the enormity of this transition. Despite the incredible impact of AI recently, the world is still struggling to appreciate how big a deal its arrival really is. We are in the process of seeing a…
# Researchers at Weill Cornell Medicine are harnessing AI to explore the universe's most complex known object, the human brain. Using AI-selected natural and synthetic images, they delve into the visual processing areas, aiming to understand organization and minimize biases. We…
# In just a few years, cutting-edge models have gone from using millions of parameters to trillions.   The amount of computation used to train the largest AI models has increased by nine orders of magnitude.   Here's what we should do next: https://www.foreignaffairs.com/world/containment-ai
# Worth a look - this AI model spots hidden signs of irregular heartbeats in regular ECGs, catching risks standard tests miss. https://www.sciencedaily.com/releases/2023/12/231212163357.htm
# I've long argued that one of the most consequential relationships of the century will be between AI and biology. This nexus, as much as any other, will shape our lives in deep and unpredictable ways. Exhibit #5672: research integrates AI with super-resolution microscopy,…
# AI - believe the hype, don't believe the hype. Let's get to work anyway https://www.cnbc.com/video/2024/01/17/weve-hit-peak-hype-of-the-ai-revolution-says-deepmind-co-founder-mustafa-suleyman.html
# "Eliminate methane emissions today, and you can quickly impact the curve of global warming." Methane is terrible for the environment, far worse than CO2. Encouraging that dozens of leaks are now detected by AI weekly. This is exactly the kind of AI application we need: solving…
# “Most people rightly argue that AI regulation is necessary, and there is a tendency to believe that it is enough. It is not.” Read @mustafasuleyman on the case for containing artificial intelligence:  https://trib.al/gO1cXp6
# Absolutely nuts to see how good genAI is getting. This is gripping:  https://www.reddit.com/r/ChatGPT/s/K4qJlnbF9l
# Chief Justice Roberts: AI won't replace lawyers, but legal research will become "unimaginable" without it He's right on both counts but this understates how radically the legal profession will be transformed. Lawyers have been insulated from disruption, but this isn't a healthy…
# "AI may become the first technology with the means to improve on itself." Hard to think of a more consequential moment than this. https://www.imf.org/en/Publications/fandd/issues/2023/12/POV-building-blocks-for-AI-governance-Bremmer-Suleyman
# Town Hall: How to Trust Technology with @robotsmarts (@OhioState), @mustafasuleyman (@InflectionAI) and @benthompson (@stratechery) #wef24 https://nitter.kavin.rocks/i/broadcasts/1djxXNDONqjGZ
# AI is rocket fuel for invention.   Our most productive decade ever is on its way  https://www.nature.com/articles/s41586-023-06221-2/
# .@mustafasuleyman (@InflectionAI) outlines the two elements that drive trust in new consumer technologies. #wef24
# Hard Power of AI with @nickclegg (@Meta), @KGeorgieva (@IMFnews), Jeremy Jurgens, @DmytroKuleba (@MFA_Ukraine), @andrewrsorkin (@NYTimes), @mustafasuleyman (@InflectionAI), @k_edtstadler and @LeoVaradkar #wef24 https://nitter.kavin.rocks/i/broadcasts/1kvJpvLeQNQKE
# "AI is truly one of the most incredible technologies of our lifetime," says DeepMind Co-Founder @MustafaSuleyman. "But at the same time, it feels like expectations about its delivery are higher than they've ever been, and maybe we have hit a kind of peak hype for this moment."
# "Tools and invention are going to make us more capable as a species... and that's what drew me to AI in the first place" Chatting with @FareedZakaria https://edition.cnn.com/videos/tech/2024/01/07/gps-0107-suleyman-on-the-future-of-ai.cnn
# Will AI return humans to their pre-Enlightenment selves? By contrast, what miraculous benefits will it entail?   Part 2 of my conversation w/ AI entrepreneur & ”The Coming Wave” author @mustafasuleyman, from today’s show
# Where is the trajectory of AI innovation headed in 2024 and beyond?   According to @mustafasuleyman, it's up to us.  Listen to Empathy in AI with co-founders of @inflectionAI, @mustafasuleyman and @reidhoffman: listen.mastersofscale.com/mu…
# In my essay w/ @IanBremmer  How AI Could Upend Geopolitics, we argue that AI will transform power and who can wield it. Policymakers are already behind the curve. Read or listen at @ForeignAffairs https://www.foreignaffairs.com/podcasts/how-ai-could-upend-geopolitics-ian-bremmer-mustafa-suleyman
# "We’ve basically taken emotional intelligence and distilled it. And I think that is going to unlock the creativity of millions and millions of people for whom that wasn’t available.” Talking AI and @heypi_ai with @guardian https://www.theguardian.com/books/2023/sep/02/i-hope-im-wrong-the-co-founder-of-deepmind-on-how-ai-threatens-to-reshape-life-as-we-know-it
# The future isn't written, it's created. Let's embrace AI and build a world that's healthier, smarter, and more sustainable.
# Forget blurry x-rays & guesswork!  AI is now spotting tooth decay 5 years earlier!  From personalized treatment plans to remote consultations, AI is revolutionizing dental care. https://hsdm.harvard.edu/news/climate-change-cavities-ai-changing-oral-health
# AI's not sci-fi. Look around. It's transforming our world.
# Not Llama 3 405B, but Nemotron 4 340B! @nvidia just released 340B dense LLM matching the original @OpenAI GPT-4 performance for chat applications and synthetic data generation. 🤯 NVIDIA does not claim ownership of any outputs generated. 💚  TL;DR: 🧮 340B Paramters with 4k…
# 👏 Hats off to Wenbo Pan for creating Faro Yi 9B DPO! With 200K context in just 16GB VRAM, it's a game-changer for efficient AI.   Dive into Wenbo’s impressive work on @huggingface here: https://huggingface.co/wenbopan/Faro-Yi-9B-DPO
# Meet the new monster in town: Nemotron-4 by @NVIDIAAI, featuring 340 billion parameters!    Get them while their hot on @huggingface🔥
# In less than 48 hours, our Stable Diffusion 3 hit 2.69M downloads and tops the ImgSys leaderboard. Huge 🙌 to our @StabilityAI teams — past, present, and future — for continuing to share great tech with the world. It's an uphill journey, but an important one.
# everything about multimodal AI in 12 mins, let's go
# an AI scoop from me on a foggy SF thursday that i thought was friday: @huggingface founder clem delangue told me that he's hearing from *10 AI startups per week* who want to sell themselves to the company. also! HF bought an AI startup, @argilla_io! https://www.bloomberg.com/news/articles/2024-06-13/more-ai-founders-looking-to-sell-startups-hugging-face-ceo-says?srnd=technology-vp
# 🔥@argilla_io is joining @huggingface 🤗 Time to double down on community, data, and open source AI!  So proud of the team, so excited to join a larger mission and amazing company  Special thanks to @osanseviero for being such a great partner during the acquisition!…
# Today is a big day for Argilla and the Open Source AI community:     We’re joining @huggingface🤗 !    Time to double down on community and data-centric, open source AI  Read all about it and ask questions:  https://huggingface.co/posts/dvilasuero/203008804842390
# And SD3 by @StabilityAI is already the #1 trending model on HF! https://huggingface.co/models
# if you were to extrapolate from solar panels, EVs, computer vision, manufacturing…  the CCP is going to get really good at AI, unfortunately  (full pod out tmrw)
# And it is out! SD3 Medium by @StabilityAI is now available on @huggingface! 🚀
# Did you know you can quickly test thousands of different AI models with simple API calls, for free?💸  🚀Excited to share my latest contribution to the Open-Source AI Cookbook that explains one of the lesser known, but highest value features on the @huggingface  Hub: the…
# In case you didn't know: open-source AI powers all AI!
# Just in case you had any doubts about the utility of OSS in mainstream AI applications, here’s a slide from an Apple developer session today. A heavy reliance on OS efforts with @huggingface at the forefront. Happy to have played a small part in this!
# Yesterday Apple strongly advocated for on-device AI with @Apple  Intelligence! Today, we know they will run ~3B LLM on device (Mac, iPhone, iPad) using fine-tuned LoRA Adapters for different tasks, claiming to outperform other 7B and 3B LLMs! 👀  What we know:  📱 On-device 3B…
# Who said you can't build a big business based on open-source AI? Congrats team @MistralAI (tens of millions of downloads from https://huggingface.co/mistralai)!
# We added idefics2 and idefics2-chatty to the Unsolvable Problem Detection Leaderboard. 🚀 This benchmark was developed to measure the robustness of VLMs by asking them questions about images that cannot be answered. #MachineLearning #AI #NLP 🧵
# Open source is built on a recognition that some foundational tools and technologies can accomplish vastly more if ubiquitous. This is true of AI where legions of academics and enthusiasts are sharing and advancing the state of the art of open models while proprietary ones stay…
# On-device AI may be a good idea 🤔
# A challenge of open-source is that it gets way less credit and publicity than it deserves. The Apple intelligence announcement is a good example of that: instead of "Apple adds chatgpt integration", the headlines should be "Apple uses open-source AI to build Apple intelligence…
# This is from Apple's State of the Union  The local model is a 3B parameter SLM that uses adapters trained for each specific feature. Diffusion model does the same thing, adapter for each style.  Anything running locally or Apple's Secure Cloud is an Apple model, not OpenAI.
# Apple is joining the public AI game with 4 new models on the Hugging Face hub! https://huggingface.co/collections/apple/openelm-instruct-models-6619ad295d7ae9f868b759ca
# Love how @Apple is advocating for on-device AI at WWDC . Local, smaller, specialized models are the future of private, secure and efficient AI.
# This is a big deal for us. When it comes to AI models, there is nothing like HuggingFace. It's popularity is massive! This should help more people discover Msty and realize how they were living without it all this time :)
# A second batch of local Generative AI apps are now live on compatible model pages on @huggingface  🔥  Welcome to the family, friends 🥰
# Instantly replace OpenAI with llama.cpp server, now with Python.  Llamanet now supports Python. In this video I take the basic Gradio OpenAI chat app from Huggingface https://www.gradio.app/guides/creating-a-chatbot-fast and add 1 line, and it's running locally with Phi-3 over llama.cpp.  cc: @ggerganov
# "I want AI to do my laundry and dishes so that I can do art and writing", not the other way around. @huggingface: OK!  https://venturebeat.com/ai/hugging-face-and-pollen-robotics-show-off-first-project-an-open-source-robot-that-does-chores/
# The US is going to lose its leadership in AI if it doesn't support more open research and open-source AI!
# It's finally possible: real-time in-browser speech recognition with OpenAI Whisper! 🤯 The model runs fully on-device using Transformers.js and ONNX Runtime Web, and supports multilingual transcription across 100 different languages! 🔥  Check out the demo (+ source code)! 👇
# We should eliminate electronic voting machines. The risk of being hacked by humans or AI, while small, is still too high.
# Wise words from a recent interview with @geoffreyhinton, one of the smartest people in the world regarding AI
# Elon Musk's warning against ChatGPT: An AI trained to lie is extremely dangerous.
# Now imagine if an AI trained in this way grows in power immensely
# It’s patently absurd that Apple isn’t smart enough to make their own AI, yet is somehow capable of ensuring that OpenAI will protect your security & privacy!  Apple has no clue what’s actually going on once they hand your data over to OpenAI. They’re selling you down the river.
# If Apple integrates OpenAI at the OS level, then Apple devices will be banned at my companies. That is an unacceptable security violation.
# Thanks Ashok!   Ashok was the first person to join the Tesla AI/Autopilot team and ultimately rose to lead all AI/Autopilot software.   Without him and our awesome team, we would just be another car company looking for an autonomy supplier that doesn’t exist.   Btw, I never…
# NEW VIDEO - Talking Tech and AI with Tim Cook! https://youtu.be/pMX2cQdPubk
# AI
# Google: "We use AI to surface a summarization of a webpage in Chrome"  Apple: “Safari uses machine learning to automatically detect relavent information and highlight it for you as you browse”
# Ok you know what? That's sick  Math Notes = write down a math problem with Apple pencil and the app solved it immediately   They're not calling it AI (they haven't said it once yet) but that's powerful
# Incoming "profound new intelligence capabilities" according to Tim... very curious how many times they say "AI" on stage this time around
# The 2 biggest rumors I've seen for iOS 18 are both hilarious:  Being able to put your icons wherever you want on your homescreen  AI-generated emojis based on what you're texting
# This is easily the most I've ever heard Apple actually say "AI" in a keynote video.
# On one hand: It seems like it's only a matter of time before Apple starts making major AI-related moves around the iPhone and iOS and buries these AI-in-a-box gadgets extremely quickly  On the other hand: Have you used Siri lately?
# NEW VIDEO - Rabbit R1: Barely Reviewable  https://youtu.be/ddTV12hErTc  This is the pinnacle of a trend that's been annoying for years: Delivering barely finished products to win a "race" and then continuing to build them after charging full price. Games, phones, cars, now AI in a box
# My favorite new AI feature: gaslighting
# Elon Musk's warning against ChatGPT: An AI trained to lie is extremely dangerous.
# Now imagine if an AI trained in this way grows in power immensely
# It’s patently absurd that Apple isn’t smart enough to make their own AI, yet is somehow capable of ensuring that OpenAI will protect your security & privacy!  Apple has no clue what’s actually going on once they hand your data over to OpenAI. They’re selling you down the river.
# If Apple integrates OpenAI at the OS level, then Apple devices will be banned at my companies. That is an unacceptable security violation.
# Thanks Ashok!   Ashok was the first person to join the Tesla AI/Autopilot team and ultimately rose to lead all AI/Autopilot software.   Without him and our awesome team, we would just be another car company looking for an autonomy supplier that doesn’t exist.   Btw, I never suggested that he say anything and I had no idea he wrote this until I saw it 10 mins ago!
# The Fusion team @GoogleDeepMind has open sourced Torax: our fast & differentiable Tokamak simulator to accelerate the use of AI in the development of practical systems for Fusion energy generation.  @jon_citrin    Paper: https://arxiv.org/abs/2406.06718 Code: https://github.com/google-deepmind/torax
# Lots of fun chatting with the great @demishassabis at @stripe Tour London. We covered: - What’s next in AI - AlphaFold 3 and AI for science  - 🇬🇧/acc and def/acc - … and much more!  https://invidious.qwik.space/D-eyJhJXXsE?si=sfQ-tGdgaJMCJm3C
# First time back in NYC since the sad passing of Prof Kahneman & Dr Kissinger – brilliant thinkers with whom I spent many fascinating hours here discussing AI & philosophy, from what it would mean for AI to have System 2 thinking, to Spinoza & using AI to understand the universe
# How does SynthID watermark AI-generated content? 🔍
# Today our team @GoogleDeepMind announced the Frontier Safety Framework — a set of exploratory protocols to proactively identify future AI capabilities, and put in place mechanisms to detect them.  Great efforts from @ancadianadragan, @AllanDafoe & others https://deepmind.google/discover/blog/introducing-the-frontier-safety-framework
# We’re sharing Project Astra: our new project focused on building a future AI assistant that can be truly helpful in everyday life. 🤝  Watch it in action, with two parts - each was captured in a single take, in real time. ↓ #GoogleIO
# For a long time, we’ve been working towards a universal AI agent that can be truly helpful in everyday life. Today at #GoogleIO we showed off our latest progress towards this: Project Astra. Here’s a video of our prototype, captured in real time.
# We think of @GoogleDeepMind as the engine room of @Google in the AI era. Thrilled to share our vision at #GoogleIO incl the latest Gemini model 1.5 Flash, Project Astra our universal AI agent effort, our new gen video model Veo, Imagen 3 & lots more!  https://deepmind.google/
# Announcing AlphaFold 3: our state-of-the-art AI model for predicting the structure and interactions of all life’s molecules. 🧬  Here’s how we built it with @IsomorphicLabs and what it means for biology. 🧵 https://dpmd.ai/3URDiNo
# Thanks to AI, new medical breakthroughs may one day move from years to mere months.  Listen to @GoogleDeepMind CEO @DemisHassabis’ full conversation with @TEDChris on how this tech is helping us solve some of science’s biggest mysteries: t.ted.com/sRLw3lQ
# My first time on the @TEDTalks stage was a really fun experience. @TEDchris and I had a great conversation about the ways AI will accelerate scientific discovery and help us solve the biggest problems facing humanity, from tackling cancer to climate: https://www.ted.com/talks/demis_hassabis_how_ai_is_unlocking_the_secrets_of_nature_and_the_universe
# Gemini 1.5 Pro has entered the (LMSys) Arena! Some highlights:  -The only "mid" tier model at the highest level alongside "top" tier models from OpenAI and Anthropic ♊️ -The model excels at multimodal, and long context (not measured here) 🐍 -This model is also state-of-the-art…
# A nice and simple guide to getting started with the Gemini 1.5 Pro in @Google AI Studio 🤖  https://medium.com/@crskilpatrick807/getting-started-with-gemini-1-5-pro-and-google-ai-studio-8f0064050ecf
# Very sad to hear of Dan Dennett's passing, I remember with great fondness the wonderful far-ranging conversation we had on AI, creativity, qualia, and of course consciousness, including Theseus's ship as regards to AI. He was a great thinker, and will be much missed.
# Soccer players have to master a range of dynamic skills, from turning and kicking to chasing a ball. How could robots do the same? ⚽  We trained our AI agents to demonstrate a range of agile behaviors using reinforcement learning.  Here’s how. 🧵 https://dpmd.ai/3vUlgjC
# Our next-generation AI model Gemini 1.5 Pro is now available in public preview on @GoogleCloud’s #VertexAI platform.  Its long-context window is already helping businesses analyze large amounts of data, build AI-powered customer service agents & more. → https://dpmd.ai/43QZrOt
# Our generative technology Imagen 2 can now create short, 4-second live images from a single prompt. 🖼  It’s available to use in @GoogleCloud’s #VertexAI platform. → https://dpmd.ai/43QZrOt #GoogleCloudNext
# Damn Gemini in AI Studio is actually better than Claude Opus.. and free!  ChatGPT4 now feels like GPT3.  In like 4 weeks I feel like we doubled intelligence.   This is amazing 🤩
# NVIDIA and Google DeepMind have collaborated to optimize Gemma models for NVIDIA AI platforms. @GoogleDevs  Experience the power of RecurrentGemma and CodeGemma for domain-specific use cases on the NVIDIA API catalog.   ➡️ https://nvda.ws/3JdYxlW
# Our new AI model Genie can create playable worlds in the style of 2D platformers - all from a single image prompt, sketch or text description. ✏️  As a foundation world model, Genie could also help us train AI agents.  Here's how. ↓ https://www.technologyreview.com/2024/02/29/1089317/google-deepminds-new-generative-model-makes-super-mario-like-games-from-scratch/
# Delighted and honoured to receive a Knighthood for services to AI. It’s been an incredible journey so far building @GoogleDeepMind over the past 15 years, helping accelerate the field and grow the UK & global AI ecosystems. Thanks to everyone who helped make this dream possible!
# If you want a hint about the future of AI, it is worth trying Gemini 1.5 with the 1M token context window, now available to everyone, apparently.  Some of my experiments: giving it a video and having it figure out a recipe, execute instructions, watching my screen, summarize work
# TacticAI is an AI system that can advise football coaches on tactics & plays https://deepmind.google/discover/blog/tacticai-ai-assistant-for-football-tactics/ This was a really fun project to work on in collaboration with my much loved Liverpool FC @LFC - fingers crossed we win the league this year to give Klopp a fitting send off!
# Excited to announce SIMA, a general AI agent for games & 3D virtual settings. It marks the first time an agent has demonstrated it can follow natural-language instructions to carry out a wide range of tasks across a large array of game worlds, similar to how a human would play.
# I gave Gemini 1.5 Pro Mr. Beast’s latest video.  It’s 22min and 347,849 tokens.  I asked it to “Reply with [NAME OF GUY ON BLUE FOOTBALL] has [TOTAL CASH PRIZE POOL] of [FOOD ITEM BEING ADVERTISED].”  Watch the model get it 100% correct.  Insane leap for AI.
# We’re announcing Duet AI for Google Workspace will now be Gemini for Google Workspace. Consumers and organizations of all sizes can access Gemini across the Workspace apps they know and love. https://blog.google/products/workspace/google-gemini-workspace/
# More Gemini news: Starting today, Gemini for Workspace is available to businesses of all sizes, and consumers can now access Gemini in their personal Gmail, Docs and more through a Google One AI Premium subscription. https://blog.google/products/workspace/google-gemini-workspace
# A hard test of Gemini 1.5 that every other AI has failed. I gave it a truly over-the-top RPG (the 352 page rulebook for 60 Years in Space) and asked it to role up a character  The instructions are scattered across many pages, and are very complicated, but Gemini seemed to get it.
# Gemini 1.5 has arrived. Pro 1.5 with 1M tokens available as an experimental feature via AI Studio and Vertex AI in private preview.   Then there’s this: In our research, we tested Gemini 1.5 on up to 2M tokens for audio, 2.8M tokens for video, and 🤯10M 🤯 tokens for text. From…
# We just crossed 100M Google One subscribers! Looking forward to building on that momentum with our new AI Premium Plan (launched yesterday) offering AI features like Gemini Advanced, plus Gemini in Gmail, Docs + more coming soon. https://one.google.com/about
# Today, we’re entering the next chapter of our Gemini era by bringing our #GeminiAI models to more of our products, starting with Bard — which will now be called Gemini. https://goo.gle/4bxymmT
# Huge congrats to Nat and team, amazing work and great use of AI! Can't wait to read some of these ancient books that were thought to be lost to the world!
# Unleash your creativity using Imagen 2: Google DeepMind’s most advanced text-to-image technology. 🎨  Try it now on Bard, @Google's latest AI experiment ImageFX and Search Generative Experience (SGE). → https://dpmd.ai/google-imagen-2
# We’re announcing a new partnership to bring Google Cloud’s generative AI technology to @SamsungMobile smartphone users around the globe, starting with the Samsung Galaxy S24 series. https://www.bloomberg.com/news/articles/2024-01-17/samsung-unpacked-event-galaxy-s24-s24-s24-ultra-phones-include-google-ai?srnd=undefined&embedded-checkout=true
# Congrats to the #AlphaGeometry team on their impressive breakthrough published today in @Nature using a neuro-symbolic hybrid AI system that can solve Maths Olympiad-level geometry problems. https://deepmind.google/discover/blog/alphageometry-an-olympiad-level-ai-system-for-geometry/
# BREAKING: Alphabet's closely watched AI bio Isomorphic Labs has inked its 1st pharma deals, CEO @demishassabis told me.  Eli Lilly and Novartis will pay $82.5 million upfront along with $2.9B in pot'l milestones to discover drugs.   Scoop 🔗: https://endpts.com/alphabets-ai-unit-isomorphic-inks-drug-discovery-deals-with-eli-lilly-novartis-for-up-to-3b/
# Our CEO @DemisHassabis spoke to the @FT about our Ai-first drug discovery ambitions and recently announced pharma collaborations with @EliLillyandCo  and @Novartis #AI #drugdiscovery #machinelearning
# ...
# I think AI agentic machine translation has huge potential for improving over traditional neural machine translation, and am releasing as open-source a demonstration I'd been playing with as a fun weekend project.  Using an agentic workflow, this demonstration (i) Prompts an LLM…
# I share @AndrewYNg's serious concerns with much of the open-source and broader AI community about California’s SB-1047 proposal.   Among many issues, the covered models definitions, shutdown capability, and enormous cost for compliance would be a huge blow to both CA and US…
# The effort to protect innovation and open source continues. I believe we’re all better off if anyone can carry out basic AI research and share their innovations. Right now, I’m deeply concerned about California's proposed law SB-1047. It’s a long, complex bill with many parts…
# New AI Agentic course! Learn to use LangGraph to build single and multi-agent LLM applications in AI Agents in LangGraph. This short course, taught by LangChain @LangChainAI  founder Harrison Chase @hwchase17 and @tavilyai founder @weiss_rotem, shows how to integrate agentic…
# We just released a new climate emulator to explore the application of Stratospheric Aerosol Injection (SAI) to mitigate global warming!  SAI uses reflective particles in the atmosphere to reflect sunlight and thereby cool Earth’s surface. Our emulator lets you explore how…
# A barrier to faster progress in generative AI is evaluations (evals), particularly of custom AI  applications that generate free-form text. Let’s say you have a multi-agent research system that includes a researcher agent and a writer agent. Would adding a fact-checking agent…
# New Agentic AI short course! AI Agentic Design Patterns with AutoGen, taught by @MSFTResearch's @Chi_Wang_ and @penn_state's @qingyun_wu, shows you how to use AutoGen to implement agentic design patterns like multi-agent collaboration, sequential and nested chat, reflection, tool…
# A good way to get started in AI is to start with coursework, which gives a systematic way to gain knowledge, and then to work on projects. For many who hear this advice, “projects” may evoke a significant undertaking that delivers value to users. But I encourage you to set a…
# Learn to deploy AI models to edge devices in our new short course Introduction to On-Device AI, created with @Qualcomm and taught by Senior Director of Engineering @krishna_srd.  I think on-device (edge) AI is an important technology trend that's enabling new low latency,…
# This week, Google announced a doubling of Gemini Pro 1.5's input context window from 1 million to 2 million tokens, and OpenAI released GPT-4o, which generates tokens 2x faster and 50% cheaper than GPT-4 Turbo and natively accepts and generates multimodal tokens. I view these…
# New agentic short course! Multi AI Agent Systems with crewAI, built with @crewAIInc's founder and CEO @joaomdmoura. In this course, you'll learn how to break down complex tasks into subtasks for multiple AI agents, each playing a specialized role, to execute.   For example, to…
# Congratulations to all my Google friends for the cool announcements at I/O!   I'm personally looking forward to Gemini with 2 million token input context window and better support for on-device AI -- should open up new opportunities for application builders!
# Congrats to OpenAI for the release of GPT-4o! 2x faster and 50% cheaper tokens will be great for everyone using agentic AI workflows.   When an agentic job that used to take 10min now takes 5min just by switching APIs, that's great progress!
# Last week, I spoke about AI and regulations at an event at the U.S. Capitol attended by legislative and business leaders. I’m encouraged by the progress the open source community has made fending off regulations that would have stifled innovation. But opponents of open source are…
# I'm glad the Washington Post's editorial board is pushing for governments to engage in exploring climate geoengineering. I believe AI climate modeling has an important role to play.   Here's the situation as I see it: - Earth is on track to a catastrophic 2-4 degrees Celsius of…
# Chatting with @GroqInc’s CEO @JonathanRoss321. Groq has super fast token generation capabilities now. And,  I was excited also to hear about his plans to scale up capacity aggressively and also expand this to other models than just LLMs! This is a good time to be building AI…
# I've really enjoyed using @crewAIInc 's tools to build multiagent AI systems -- in addition to being productive, it's also fun to use! It was great hanging out with its creator @joaomdmoura to chat about best practices for building agentic workflows.
# New short course with @MistralAI !  Mistral's open-source Mixtral 8x7B model uses a "mixture of experts" (MoE) architecture. Unlike a standard transformer, an MoE model has multiple expert feed-forward networks (8 in this case), with a gating network selecting two experts at…
# Multi-agent collaboration has emerged as a key AI agentic design pattern. Given a complex task like writing software, a multi-agent approach would break down the task into subtasks to be executed by different roles -- such as a software engineer, product manager, designer, QA…
# Planning is a key agentic AI design pattern in which we use a large language model (LLM) to autonomously decide on what sequence of steps to execute to accomplish a larger task. For example, if we ask an agent to do online research on a given topic, we might use an LLM to break…
# The Financial Times has a great article on Renate Nyborg @renate's work on @meeno_official , written by @madhumita29.   The article is paywalled, but I appreciate Renate (as well as Harvard's @ronivey)'s leadership speaking about the dangers of the AI fake girlfriend/boyfriend…
# The task-based analysis of how AI affects jobs is a powerful technique for creating business value. It was pioneered by Workhelix’s @erikbryn et al. Now, Workhelix has developed technology to apply this at scale, by automatically examining a company’s job descriptions,…
# Tool use, in which an LLM is given functions it can request to call for gathering information, taking action, or manipulating data, is a key design pattern of AI agentic workflows. You may be familiar with LLM-based systems that can perform a web search or execute code. Some of…
# Last week, I described four design patterns for AI agentic workflows that I believe will drive significant progress this year: Reflection, Tool use, Planning and Multi-agent collaboration. Instead of having an LLM generate its final output directly, an agentic workflow prompts…
# I think AI agentic workflows will drive massive AI progress this year — perhaps even more than the next generation of foundation models. This is an important trend, and I urge everyone who works in AI to pay attention to it.  Today, we mostly use LLMs in zero-shot mode, prompting…
# Very excited about this new collaboration with DeepLearning.AI team @AndrewYNg, HF team @_marcsun @mariaKhalusova  !  You will learn how to get started with transformers library and HF ecosystem and learn how to build AI applications from scratch - enjoy!
# Together with @AndrewYNg and the DeepLearning.AI team, we're excited to launch this new, free course taught by @asangani7. More in the announcement below ⬇️
# Super thrilled to team up with AI legend @AndrewYNg and Deeplearning.ai  to launch a free Llama 2 course on DeepLearning’s platform. This will help jump-start your journey to using Llama for your Gen AI applications!  @Meta @AIatMeta @DeepLearningAI
# New short course: Prompt Engineering with Llama 2, built in collaboration with Meta @AIatMeta, and taught by @asangani7! Meta's Llama 2 has been game-changing for AI. Building with open source lets you control your own data, scrutinize errors, update (or not) the models as you…
# Congratulations @hwchase17 and the whole @LangChainAI team! Love the work you're doing to make it easy for others to build LLM apps.
# Like @AndrewYNg, I have observed a definite shift in the prevalent discourse about AI at Davos: - Few people still talk about existential risk, and few people believe that current technology, even scaled up, will present an existential risk. - Everyone agrees that open source AI…
# My takeaways from attending WEF at Davos last week: - There were lots of discussions on business implementation of AI. My top two tips: (i) Pretty much all knowledge workers can benefit from using GenAI now, but most will need training. (ii) Task-based analysis of jobs is helping…
# Our first Generative AI short course in JavaScript!  GitHub recently reported that JavaScript is again the world’s most popular programming language. To support web developers exploring and developing with generative AI, we just launched a new short course in JavaScript taught by…
# After reading the @nytimes lawsuit against @OpenAI and @Microsoft, I find my sympathies more with OpenAI and Microsoft than with the NYT.   The suit: (1) Claims, among other things, that OpenAI and Microsoft used millions of copyrighted NYT articles to train their models (2)…
# New short course on advanced retrieval for RAG (retrieval augmented generation)!   RAG fetches relevant documents to give context to an LLM. In Advanced Retrieval for AI with Chroma, taught by @trychroma founder @atroyn, you’ll learn: (i) Query expansion using an LLM to rewrite…
# What does 2024 hold for AI? ​​In the latest edition of The Batch, @agermanidis @sarahookr @percyliang @SashaMTL @tamati_biskit and @kevin_scott outline their hopes for AI for this year ahead.   Their wide ranging articles explore new AI tools for storytelling, inclusion, AI…
# "Do we think the world is better off with more or less intelligence?" is the AI-specific version of the general tech Q "Do we think the world is better off with more or less material abundance and higher standards of living?" Should be slam dunk, and yet. https://www.ft.com/content/2dc07f9e-d2a9-4d98-b746-b051f9352be3
# How likely are AI doomsday scenarios? I spoke at the US Senate AI Insight forum organized by Senators Chuck Schumer (D-NY), Martin Heinrich (D-NM), Mike Rounds (R-SD), and Todd Young (R-IN), and explained why I think they're very unlikely.  AI systems aligned with RLHF already…
# Had lunch with a group of distinguished climate scientists to discuss applying AI to climate modeling to advance the science of stratospheric aerosol injection (SAI) for cooling Earth. AI can help figure out if this is actually a good idea (which we do not currently know).…
# In AI, the ratio of attention on hypothetical, future, forms of harm to actual, current, realized forms of harm seems out of whack.   Many of the hypothetical forms of harm, like AI "taking over", are based on highly questionable hypotheses about what technology that does not…
# I hope AI can make a difference to climate change, by advancing the science underlying the possibility of cooling Earth via stratospheric aerosol injection (SAI).   To be clear, I don't think SAI is a good idea. But I also don't think it's a bad idea. We just don't know! We need…
# Just had a great meeting with @VogelMiriam of @ai_equal about how to make sure AI supports rather than undermines democracy. I'm inspired by the work that EqualAI has been doing with policy makers and on  governance to make sure AI benefits everyone!
# Thank you to the entire OpenAI team, including esp @sama @gdb @miramurati, for your incredible contributions to AI. It is tragic that the foolish decisions of a few people are hurting everyone. We love and are rooting for every one of you.❤️
# Sending love to everyone at OpenAI. Whatever happens next, many of us are wishing the best for all of you and for the amazing company you've built. ❤️
# Great piece by @arthurmensch on EU AI Act: - What's good: Thinking about the risk of different AI applications/products and mitigating that   - What's very bad: Hampering basic foundation model technology because of vague fears and in ways that hamper open-source & competition
# I spoke at WEF and APEC this week about AI regulation. My message: Governments should not outlaw open source software or pass regulations that stifle open source development.  More details, including the complex forces at play, in The Batch below:  https://www.deeplearning.ai/the-batch/issue-223/
# New short course! Quality and Safety for LLM Applications, created with @WhyLabs (an AI Fund portfolio company) and taught by @bernease, shows how you can mitigate hallucinations, data leakage, and jailbreaks. Come learn more in the course, available now! https://www.deeplearning.ai/short-courses/quality-safety-llm-applications/
# Just got the data: Generative AI for Everyone is the fasting growing course on Coursera this year, with 43K enrollments in first 7 days. Thanks everyone who's signed up!  Come join us: Learn about how GenAI works and how to use it! https://www.coursera.org/learn/generative-ai-for-everyone
# Argh, my son just figured out how to steal chocolate from the pantry, and made a brown, gooey mess.   Worried about how hard it is to align AI? Right now I feel I have better tools to align AI with human values than align humans with human values, at least in the case of my 2…
# This is a great website, and documents via news clippings the alarm over many beneficial innovations, such as electricity, bicycles, elevators, radio, etc: https://pessimistsarchive.org/   After the current wave of alarm over AI human extinction dies down, I wonder if statements about…
# A nice piece by @AndrewYNg arguing that irrational fears about AI should not cause governments to regulate open source AI models out of existence.
# Bill Gurley @bgurley has a great talk on regulatory capture and how it's crushed competition and innovation in many industries. How can we stop this pattern from playing out in AI regulation?   Here's his talk: https://piped.video/watch?v=F9cO3-MLHOM
# Laws to ensure AI applications are safe, fair, and transparent are needed. But the White House's use of the Defense Production Act—typically reserved for war or national emergencies—distorts AI through the lens of security, for example with phrases like "companies developing any…
# My greatest fear for the future of AI is if overhyped risks (such as human extinction) lets tech lobbyists get enacted stifling regulations that suppress open-source and crush innovation.   Read more in our Halloween special issue of the Batch: https://www.deeplearning.ai/the-batch/issue-220/
# Join me for a livestream, ”Building Computer Vision Applications," on Monday, Nov 6, hosted by Landing AI! Please register here: https://landing.ai/building-computer-vision-applications/   I’ll discuss the practical aspects of building a vision application, including how to (i) Identify and scope a vision…
# I’m teaching a new course: Generative AI for Everyone, which is coming soon!  Learn how Generative AI works, how to use it in professional or personal settings, and how it will affect jobs, businesses and society. This course is accessible to everyone, and assumes no prior coding…
# Attending ⁦@geoffreyhinton⁩’s retirement celebration at Google with old friends. Thank you for everything you’ve done for AI! ⁦@JeffDean⁩ ⁦@quocleix⁩
# While AI can’t solve climate change, it will be a key part of the solution.   I’m thrilled to see the work of Dylan Keil and team at  @BearingAI on reducing carbon emissions in shipping. Ships guided by Bearing have sailed over 75 million miles — the equivalent of sailing 3000x…
# Many AI-savvy programmers are now coding very differently than before, by using LLMs to help with their work. You’ll learn these emerging best practices in “Pair Programming with a Large Language Model,” by Google's @lmoroney.   This short course covers using LLMs to simplify and…
# Looking for AI project ideas for a large company or industry sector? I share in The Batch a brainstorming recipe: (i) break jobs down into tasks, (ii) evaluate common tasks for AI assistance or automation, (iii) assess value. Check out details & examples here:…

# %% [markdown]
# ## Creating a Data Frame which consists  of word and their frequency

# %%
import pandas as pd
from wordcloud import WordCloud
import plotly.express as px

# Initialize an empty dictionary to store word frequency data
word_freq_dict = {'Topic': [], 'Word': [], 'Frequency': []}

# Creating word clouds and bar plots for each topic
for topic_id in range(lda_model.num_topics):
    # Generate word cloud image
    wordcloud_dict = dict(lda_model.show_topic(topic_id, 10))
    
    # Add topic ID to the dictionary
    topic_word_freq_data = {'Topic': f"Topic {topic_id}"}
    
    # Update the dictionary with word frequency data
    for word, freq in wordcloud_dict.items():
        topic_word_freq_data['Word'] = word
        topic_word_freq_data['Frequency'] = freq
        word_freq_dict['Topic'].append(topic_word_freq_data['Topic'])
        word_freq_dict['Word'].append(topic_word_freq_data['Word'])
        word_freq_dict['Frequency'].append(topic_word_freq_data['Frequency'])

# Convert dictionary to DataFrame
word_freq_data = pd.DataFrame(word_freq_dict)

# Print the DataFrame
print(word_freq_data)
# Out:
#       Topic        Word  Frequency
# 0   Topic 0         new   0.005699
# 1   Topic 0       Apple   0.005610
# 2   Topic 0         Pro   0.003817
# 3   Topic 0    everyone   0.003804
# 4   Topic 0      Gemini   0.003567
# ..      ...         ...        ...
# 95  Topic 9         new   0.003816
# 96  Topic 9        test   0.003507
# 97  Topic 9          15   0.003238
# 98  Topic 9  technology   0.003208
# 99  Topic 9        week   0.003125
#
# [100 rows x 3 columns]

# %%
import pandas as pd
import plotly.express as px


word_freq_data_1 = word_freq_data

# Function to display related tweets for a given word
def display_related_tweets(word):
    # Add your logic here to display related tweets for the clicked word
    print(f"Related tweets for the word '{word}'")

# Plot the interactive word cloud
fig = px.scatter(word_freq_data_1, x='Word', y='Frequency', text='Word', size='Frequency', color='Topic', 
                 title='Interactive Word Cloud')
fig.update_traces(marker={'opacity': 0.5}, selector=dict(mode='markers'))
fig.update_layout(
    title={'x': 0.5, 'y': 0.9, 'xanchor': 'center', 'yanchor': 'top'},
    hoverlabel={'bgcolor': 'white', 'font_size': 16, 'font_family': 'Arial'},
    hovermode='closest'
)
fig.update_traces(textposition='middle center', selector=dict(type='scatter', mode='markers'))
fig.show()
